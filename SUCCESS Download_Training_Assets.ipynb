# %% [markdown]
# <a href="https://colab.research.google.com/github/ukik/AI-Song-Cover-RVC/blob/main/SUCCESS%20Download_Training_Assets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![ko-fi](https://ko-fi.com/img/githubbutton_sm.svg)](https://ko-fi.com/R6R7AH1FA)
# <a href="https://trakteer.id/ardha27">
#     <img src="https://cdn.trakteer.id/images/embed/trbtn-red-1.png" alt="Trakteer" height="35">
# </a>

# %%
#@title Mount Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title Cloning Github
# !rm /content/drive/MyDrive/assets/KiwKiw.zip
# !git clone https://github.com/RVC-Project/Retrieval-based-Voice-Conversion-WebUI.git
# !mv /content/Retrieval-based-Voice-Conversion-WebUI /content/KiwKiw
# Out:
# rm: cannot remove '/content/drive/MyDrive/assets/KiwKiw.zip': No such file or directory
# Cloning into 'Retrieval-based-Voice-Conversion-WebUI'...
# remote: Enumerating objects: 4593, done.
# remote: Total 4593 (delta 0), reused 0 (delta 0), pack-reused 4593 (from 1)
# Receiving objects: 100% (4593/4593), 14.35 MiB | 59.99 MiB/s, done.
# Resolving deltas: 100% (2864/2864), done.

# %%
#@title Install aria2
# !apt -y install -qq aria2
# Out:
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 1 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 117532 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...

# %%
#@title Download Pretrained Model for Training
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/D32k.pth -d /content/KiwKiw/assets/pretrained -o D32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/D40k.pth -d /content/KiwKiw/assets/pretrained -o D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/D48k.pth -d /content/KiwKiw/assets/pretrained -o D48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/G32k.pth -d /content/KiwKiw/assets/pretrained -o G32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/G40k.pth -d /content/KiwKiw/assets/pretrained -o G40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/G48k.pth -d /content/KiwKiw/assets/pretrained -o G48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0D32k.pth -d /content/KiwKiw/assets/pretrained -o f0D32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0D40k.pth -d /content/KiwKiw/assets/pretrained -o f0D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0D48k.pth -d /content/KiwKiw/assets/pretrained -o f0D48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0G32k.pth -d /content/KiwKiw/assets/pretrained -o f0G32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0G40k.pth -d /content/KiwKiw/assets/pretrained -o f0G40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0G48k.pth -d /content/KiwKiw/assets/pretrained -o f0G48k.pth

#RVC V2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/D32k.pth -d /content/KiwKiw/assets/pretrained_v2 -o D32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/D40k.pth -d /content/KiwKiw/assets/pretrained_v2 -o D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/D48k.pth -d /content/KiwKiw/assets/pretrained_v2 -o D48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/G32k.pth -d /content/KiwKiw/assets/pretrained_v2 -o G32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/G40k.pth -d /content/KiwKiw/assets/pretrained_v2 -o G40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/G48k.pth -d /content/KiwKiw/assets/pretrained_v2 -o G48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0D32k.pth -d /content/KiwKiw/assets/pretrained_v2 -o f0D32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0D40k.pth -d /content/KiwKiw/assets/pretrained_v2 -o f0D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0D48k.pth -d /content/KiwKiw/assets/pretrained_v2 -o f0D48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0G32k.pth -d /content/KiwKiw/assets/pretrained_v2 -o f0G32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0G40k.pth -d /content/KiwKiw/assets/pretrained_v2 -o f0G40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0G48k.pth -d /content/KiwKiw/assets/pretrained_v2 -o f0G48k.pth
# Out:
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ae6eae|OK  |   328MiB/s|/content/KiwKiw/assets/pretrained/D32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e1442f|OK  |   101MiB/s|/content/KiwKiw/assets/pretrained/D40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ce9887|OK  |   100MiB/s|/content/KiwKiw/assets/pretrained/D48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 554135|OK  |    87MiB/s|/content/KiwKiw/assets/pretrained/G32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a9ae28|OK  |    71MiB/s|/content/KiwKiw/assets/pretrained/G40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ef823f|OK  |   212MiB/s|/content/KiwKiw/assets/pretrained/G48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 2d22bd|OK  |    81MiB/s|/content/KiwKiw/assets/pretrained/f0D32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 2ea507|OK  |    87MiB/s|/content/KiwKiw/assets/pretrained/f0D40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c962a2|OK  |    92MiB/s|/content/KiwKiw/assets/pretrained/f0D48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 9a1030|OK  |    25MiB/s|/content/KiwKiw/assets/pretrained/f0G32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# fa17f2|OK  |    79MiB/s|/content/KiwKiw/assets/pretrained/f0G40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 15f257|OK  |   227MiB/s|/content/KiwKiw/assets/pretrained/f0G48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3a113f|OK  |   429MiB/s|/content/KiwKiw/assets/pretrained_v2/D32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 05f346|OK  |   146MiB/s|/content/KiwKiw/assets/pretrained_v2/D40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e7d723|OK  |   138MiB/s|/content/KiwKiw/assets/pretrained_v2/D48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# b8733b|OK  |    82MiB/s|/content/KiwKiw/assets/pretrained_v2/G32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 9172c4|OK  |    79MiB/s|/content/KiwKiw/assets/pretrained_v2/G40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 87bee2|OK  |   202MiB/s|/content/KiwKiw/assets/pretrained_v2/G48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 33008a|OK  |   182MiB/s|/content/KiwKiw/assets/pretrained_v2/f0D32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 678f56|OK  |   123MiB/s|/content/KiwKiw/assets/pretrained_v2/f0D40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 807c5f|OK  |    96MiB/s|/content/KiwKiw/assets/pretrained_v2/f0D48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ed23f9|OK  |    62MiB/s|/content/KiwKiw/assets/pretrained_v2/f0G32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ee9970|OK  |   192MiB/s|/content/KiwKiw/assets/pretrained_v2/f0G40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# b23fd4|OK  |    61MiB/s|/content/KiwKiw/assets/pretrained_v2/f0G48k.pth
#
# Status Legend:
# (OK):download completed.

# %%
#@title Download hubert_base
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/hubert_base.pt -d /content/KiwKiw/assets/hubert -o hubert_base.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/rmvpe.pt -d /content/KiwKiw/assets/rmvpe -o rmvpe.pt
# Out:
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 4ef00c|OK  |   159MiB/s|/content/KiwKiw/assets/hubert/hubert_base.pt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 58e237|OK  |   171MiB/s|/content/KiwKiw/assets/rmvpe/rmvpe.pt
#
# Status Legend:
# (OK):download completed.

# %%
#!zip -rq - KiwKiw | split -b 500M - KiwKiw.zip.part_

# %%
# @title Zip and Copy to Drive
# bikin timeout colab, solusi pakai v5e-1 TPU (WAJIB)
# !zip -r KiwKiw.zip KiwKiw
# !mkdir -p /content/drive/MyDrive/assets/ && cp KiwKiw.zip /content/drive/MyDrive/assets/KiwKiw.zip
# Out:
#   adding: KiwKiw/ (stored 0%)
#   adding: KiwKiw/logs/ (stored 0%)
#   adding: KiwKiw/logs/mute/ (stored 0%)
#   adding: KiwKiw/logs/mute/0_gt_wavs/ (stored 0%)
#   adding: KiwKiw/logs/mute/0_gt_wavs/mute32k.wav (deflated 100%)
#   adding: KiwKiw/logs/mute/0_gt_wavs/mute40k.wav (deflated 100%)
#   adding: KiwKiw/logs/mute/0_gt_wavs/mute48k.wav (deflated 100%)
#   adding: KiwKiw/logs/mute/2b-f0nsf/ (stored 0%)
#   adding: KiwKiw/logs/mute/2b-f0nsf/mute.wav.npy (deflated 97%)
#   adding: KiwKiw/logs/mute/2a_f0/ (stored 0%)
#   adding: KiwKiw/logs/mute/2a_f0/mute.wav.npy (deflated 94%)
#   adding: KiwKiw/logs/mute/3_feature256/ (stored 0%)
#   adding: KiwKiw/logs/mute/3_feature256/mute.npy (deflated 48%)
#   adding: KiwKiw/logs/mute/1_16k_wavs/ (stored 0%)
#   adding: KiwKiw/logs/mute/1_16k_wavs/mute.wav (deflated 100%)
#   adding: KiwKiw/logs/mute/3_feature768/ (stored 0%)
#   adding: KiwKiw/logs/mute/3_feature768/mute.npy (deflated 48%)
#   adding: KiwKiw/i18n/ (stored 0%)
#   adding: KiwKiw/i18n/locale_diff.py (deflated 60%)
#   adding: KiwKiw/i18n/i18n.py (deflated 57%)
#   adding: KiwKiw/i18n/locale/ (stored 0%)
#   adding: KiwKiw/i18n/locale/es_ES.json (deflated 60%)
#   adding: KiwKiw/i18n/locale/pt_BR.json (deflated 57%)
#   adding: KiwKiw/i18n/locale/ja_JP.json (deflated 62%)
#   adding: KiwKiw/i18n/locale/it_IT.json (deflated 59%)
#   adding: KiwKiw/i18n/locale/zh_HK.json (deflated 62%)
#   adding: KiwKiw/i18n/locale/tr_TR.json (deflated 58%)
#   adding: KiwKiw/i18n/locale/zh_SG.json (deflated 62%)
#   adding: KiwKiw/i18n/locale/zh_CN.json (deflated 73%)
#   adding: KiwKiw/i18n/locale/ko_KR.json (deflated 59%)
#   adding: KiwKiw/i18n/locale/ru_RU.json (deflated 66%)
#   adding: KiwKiw/i18n/locale/zh_TW.json (deflated 62%)
#   adding: KiwKiw/i18n/locale/en_US.json (deflated 57%)
#   adding: KiwKiw/i18n/locale/fr_FR.json (deflated 60%)
#   adding: KiwKiw/i18n/scan_i18n.py (deflated 59%)
#   adding: KiwKiw/requirements-win-for-realtime_vc_gui-dml.txt (deflated 42%)
#   adding: KiwKiw/infer/ (stored 0%)
#   adding: KiwKiw/infer/lib/ (stored 0%)
#   adding: KiwKiw/infer/lib/rtrvc.py (deflated 74%)
#   adding: KiwKiw/infer/lib/slicer2.py (deflated 75%)
#   adding: KiwKiw/infer/lib/audio.py (deflated 51%)
#   adding: KiwKiw/infer/lib/jit/ (stored 0%)
#   adding: KiwKiw/infer/lib/jit/get_hubert.py (deflated 71%)
#   adding: KiwKiw/infer/lib/jit/get_rmvpe.py (deflated 42%)
#   adding: KiwKiw/infer/lib/jit/__init__.py (deflated 76%)
#   adding: KiwKiw/infer/lib/jit/get_synthesizer.py (deflated 64%)
#   adding: KiwKiw/infer/lib/rmvpe.py (deflated 76%)
#   adding: KiwKiw/infer/lib/uvr5_pack/ (stored 0%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/ (stored 0%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/layers_new.py (deflated 74%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/layers_537238KB.py (deflated 78%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/nets.py (deflated 74%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/nets_123821KB.py (deflated 74%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/nets_537227KB.py (deflated 74%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/nets_new.py (deflated 74%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/model_param_init.py (deflated 65%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/nets_33966KB.py (deflated 74%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/nets_537238KB.py (deflated 74%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/layers_123821KB.py (deflated 77%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/layers_123812KB .py (deflated 77%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/nets_123812KB.py (deflated 74%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/spec_utils.py (deflated 79%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/ (stored 0%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/3band_44100.json (deflated 64%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/1band_sr44100_hl512.json (deflated 46%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/2band_32000.json (deflated 57%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/4band_44100.json (deflated 69%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/4band_v3.json (deflated 71%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/4band_44100_msb2.json (deflated 68%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/4band_44100_reverse.json (deflated 69%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/4band_44100_sw.json (deflated 68%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/4band_v2_sn.json (deflated 68%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/3band_44100_msb2.json (deflated 63%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/ensemble.json (deflated 64%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/3band_44100_mid.json (deflated 64%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/2band_48000.json (deflated 58%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/1band_sr44100_hl512_cut.json (deflated 45%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/2band_44100_lofi.json (deflated 57%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/1band_sr44100_hl1024.json (deflated 47%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/1band_sr16000_hl512.json (deflated 46%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/4band_v2.json (deflated 69%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/1band_sr44100_hl256.json (deflated 47%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/1band_sr33075_hl384.json (deflated 46%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/4band_44100_mid.json (deflated 68%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/1band_sr32000_hl512.json (deflated 46%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/modelparams/4band_44100_msb.json (deflated 68%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/layers.py (deflated 77%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/layers_537227KB.py (deflated 78%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/layers_33966KB.py (deflated 78%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/dataset.py (deflated 72%)
#   adding: KiwKiw/infer/lib/uvr5_pack/lib_v5/nets_61968KB.py (deflated 74%)
#   adding: KiwKiw/infer/lib/uvr5_pack/name_params.json (deflated 90%)
#   adding: KiwKiw/infer/lib/uvr5_pack/utils.py (deflated 69%)
#   adding: KiwKiw/infer/lib/infer_pack/ (stored 0%)
#   adding: KiwKiw/infer/lib/infer_pack/commons.py (deflated 69%)
#   adding: KiwKiw/infer/lib/infer_pack/models_onnx.py (deflated 82%)
#   adding: KiwKiw/infer/lib/infer_pack/attentions.py (deflated 81%)
#   adding: KiwKiw/infer/lib/infer_pack/modules/ (stored 0%)
#   adding: KiwKiw/infer/lib/infer_pack/modules/F0Predictor/ (stored 0%)
#   adding: KiwKiw/infer/lib/infer_pack/modules/F0Predictor/PMF0Predictor.py (deflated 73%)
#   adding: KiwKiw/infer/lib/infer_pack/modules/F0Predictor/DioF0Predictor.py (deflated 71%)
#   adding: KiwKiw/infer/lib/infer_pack/modules/F0Predictor/F0Predictor.py (deflated 68%)
#   adding: KiwKiw/infer/lib/infer_pack/modules/F0Predictor/HarvestF0Predictor.py (deflated 70%)
#   adding: KiwKiw/infer/lib/infer_pack/modules/F0Predictor/__init__.py (stored 0%)
#   adding: KiwKiw/infer/lib/infer_pack/transforms.py (deflated 79%)
#   adding: KiwKiw/infer/lib/infer_pack/modules.py (deflated 84%)
#   adding: KiwKiw/infer/lib/infer_pack/attentions_onnx.py (deflated 80%)
#   adding: KiwKiw/infer/lib/infer_pack/models.py (deflated 85%)
#   adding: KiwKiw/infer/lib/infer_pack/onnx_inference.py (deflated 73%)
#   adding: KiwKiw/infer/lib/train/ (stored 0%)
#   adding: KiwKiw/infer/lib/train/process_ckpt.py (deflated 80%)
#   adding: KiwKiw/infer/lib/train/data_utils.py (deflated 82%)
#   adding: KiwKiw/infer/lib/train/losses.py (deflated 68%)
#   adding: KiwKiw/infer/lib/train/mel_processing.py (deflated 71%)
#   adding: KiwKiw/infer/lib/train/utils.py (deflated 75%)
#   adding: KiwKiw/infer/modules/ (stored 0%)
#   adding: KiwKiw/infer/modules/uvr5/ (stored 0%)
#   adding: KiwKiw/infer/modules/uvr5/vr.py (deflated 86%)
#   adding: KiwKiw/infer/modules/uvr5/mdxnet.py (deflated 70%)
#   adding: KiwKiw/infer/modules/uvr5/modules.py (deflated 73%)
#   adding: KiwKiw/infer/modules/onnx/ (stored 0%)
#   adding: KiwKiw/infer/modules/onnx/export.py (deflated 52%)
#   adding: KiwKiw/infer/modules/ipex/ (stored 0%)
#   adding: KiwKiw/infer/modules/ipex/hijacks.py (deflated 80%)
#   adding: KiwKiw/infer/modules/ipex/attention.py (deflated 85%)
#   adding: KiwKiw/infer/modules/ipex/__init__.py (deflated 79%)
#   adding: KiwKiw/infer/modules/ipex/gradscaler.py (deflated 66%)
#   adding: KiwKiw/infer/modules/vc/ (stored 0%)
#   adding: KiwKiw/infer/modules/vc/pipeline.py (deflated 74%)
#   adding: KiwKiw/infer/modules/vc/__init__.py (stored 0%)
#   adding: KiwKiw/infer/modules/vc/modules.py (deflated 75%)
#   adding: KiwKiw/infer/modules/vc/utils.py (deflated 57%)
#   adding: KiwKiw/infer/modules/train/ (stored 0%)
#   adding: KiwKiw/infer/modules/train/extract/ (stored 0%)
#   adding: KiwKiw/infer/modules/train/extract/extract_f0_rmvpe_dml.py (deflated 66%)
#   adding: KiwKiw/infer/modules/train/extract/extract_f0_print.py (deflated 69%)
#   adding: KiwKiw/infer/modules/train/extract/extract_f0_rmvpe.py (deflated 66%)
#   adding: KiwKiw/infer/modules/train/preprocess.py (deflated 69%)
#   adding: KiwKiw/infer/modules/train/extract_feature_print.py (deflated 60%)
#   adding: KiwKiw/infer/modules/train/train.py (deflated 78%)
#   adding: KiwKiw/venv.sh (deflated 3%)
#   adding: KiwKiw/docker-compose.yml (deflated 48%)
#   adding: KiwKiw/infer-web.py (deflated 80%)
#   adding: KiwKiw/requirements-py311.txt (deflated 38%)
#   adding: KiwKiw/.github/ (stored 0%)
#   adding: KiwKiw/.github/workflows/ (stored 0%)
#   adding: KiwKiw/.github/workflows/pull_format.yml (deflated 55%)
#   adding: KiwKiw/.github/workflows/unitest.yml (deflated 58%)
#   adding: KiwKiw/.github/workflows/docker.yml (deflated 55%)
#   adding: KiwKiw/.github/workflows/genlocale.yml (deflated 59%)
#   adding: KiwKiw/.github/workflows/push_format.yml (deflated 61%)
#   adding: KiwKiw/.github/workflows/sync_dev.yml (deflated 42%)
#   adding: KiwKiw/.github/PULL_REQUEST_TEMPLATE.md (deflated 44%)
#   adding: KiwKiw/Dockerfile (deflated 70%)
#   adding: KiwKiw/assets/ (stored 0%)
#   adding: KiwKiw/assets/Synthesizer_inputs.pth (deflated 32%)
#   adding: KiwKiw/assets/hubert/ (stored 0%)
#   adding: KiwKiw/assets/hubert/hubert_inputs.pth (deflated 99%)
#   adding: KiwKiw/assets/hubert/hubert_base.pt (deflated 7%)
#   adding: KiwKiw/assets/hubert/.gitignore (stored 0%)
#   adding: KiwKiw/assets/pretrained_v2/ (stored 0%)
#   adding: KiwKiw/assets/pretrained_v2/f0G48k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained_v2/f0D40k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained_v2/D48k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained_v2/G40k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained_v2/D40k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained_v2/G32k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained_v2/f0D32k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained_v2/f0G40k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained_v2/f0G32k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained_v2/D32k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained_v2/.gitignore (stored 0%)
#   adding: KiwKiw/assets/pretrained_v2/G48k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained_v2/f0D48k.pth (deflated 7%)
#   adding: KiwKiw/assets/uvr5_weights/ (stored 0%)
#   adding: KiwKiw/assets/uvr5_weights/.gitignore (stored 0%)
#   adding: KiwKiw/assets/weights/ (stored 0%)
#   adding: KiwKiw/assets/weights/.gitignore (stored 0%)
#   adding: KiwKiw/assets/rmvpe/ (stored 0%)
#   adding: KiwKiw/assets/rmvpe/rmvpe.pt (deflated 9%)
#   adding: KiwKiw/assets/rmvpe/rmvpe_inputs.pth (deflated 98%)
#   adding: KiwKiw/assets/rmvpe/.gitignore (stored 0%)
#   adding: KiwKiw/assets/indices/ (stored 0%)
#   adding: KiwKiw/assets/indices/.gitignore (stored 0%)
#   adding: KiwKiw/assets/pretrained/ (stored 0%)
#   adding: KiwKiw/assets/pretrained/f0G48k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained/f0D40k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained/D48k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained/G40k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained/D40k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained/G32k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained/f0D32k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained/f0G40k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained/f0G32k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained/D32k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained/.gitignore (stored 0%)
#   adding: KiwKiw/assets/pretrained/G48k.pth (deflated 8%)
#   adding: KiwKiw/assets/pretrained/f0D48k.pth (deflated 8%)
#   adding: KiwKiw/README.md (deflated 54%)
#   adding: KiwKiw/Retrieval_based_Voice_Conversion_WebUI.ipynb (deflated 82%)
#   adding: KiwKiw/configs/ (stored 0%)
#   adding: KiwKiw/configs/config.py (deflated 75%)
#   adding: KiwKiw/configs/config.json (deflated 45%)
#   adding: KiwKiw/configs/v2/ (stored 0%)
#   adding: KiwKiw/configs/v2/32k.json (deflated 57%)
#   adding: KiwKiw/configs/v2/48k.json (deflated 57%)
#   adding: KiwKiw/configs/inuse/ (stored 0%)
#   adding: KiwKiw/configs/inuse/v2/ (stored 0%)
#   adding: KiwKiw/configs/inuse/v2/.gitignore (stored 0%)
#   adding: KiwKiw/configs/inuse/.gitignore (stored 0%)
#   adding: KiwKiw/configs/inuse/v1/ (stored 0%)
#   adding: KiwKiw/configs/inuse/v1/.gitignore (stored 0%)
#   adding: KiwKiw/configs/v1/ (stored 0%)
#   adding: KiwKiw/configs/v1/40k.json (deflated 57%)
#   adding: KiwKiw/configs/v1/32k.json (deflated 57%)
#   adding: KiwKiw/configs/v1/48k.json (deflated 57%)
#   adding: KiwKiw/go-realtime-gui.bat (stored 0%)
#   adding: KiwKiw/api_231006.py (deflated 78%)
#   adding: KiwKiw/requirements-amd.txt (deflated 39%)
#   adding: KiwKiw/go-web-dml.bat (deflated 20%)
#   adding: KiwKiw/environment_dml.yaml (deflated 64%)
#   adding: KiwKiw/.git/ (stored 0%)
#   adding: KiwKiw/.git/logs/ (stored 0%)
#   adding: KiwKiw/.git/logs/HEAD (deflated 26%)
#   adding: KiwKiw/.git/logs/refs/ (stored 0%)
#   adding: KiwKiw/.git/logs/refs/remotes/ (stored 0%)
#   adding: KiwKiw/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: KiwKiw/.git/logs/refs/remotes/origin/HEAD (deflated 26%)
#   adding: KiwKiw/.git/logs/refs/heads/ (stored 0%)
#   adding: KiwKiw/.git/logs/refs/heads/main (deflated 26%)
#   adding: KiwKiw/.git/HEAD (stored 0%)
#   adding: KiwKiw/.git/objects/ (stored 0%)
#   adding: KiwKiw/.git/objects/pack/ (stored 0%)
#   adding: KiwKiw/.git/objects/pack/pack-ffc816940e47933f4594c4be713b86c378986295.pack (deflated 0%)
#   adding: KiwKiw/.git/objects/pack/pack-ffc816940e47933f4594c4be713b86c378986295.idx (deflated 2%)
#   adding: KiwKiw/.git/objects/info/ (stored 0%)
#   adding: KiwKiw/.git/config (deflated 31%)
#   adding: KiwKiw/.git/hooks/ (stored 0%)
#   adding: KiwKiw/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: KiwKiw/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: KiwKiw/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: KiwKiw/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: KiwKiw/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: KiwKiw/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: KiwKiw/.git/hooks/post-update.sample (deflated 27%)
#   adding: KiwKiw/.git/hooks/update.sample (deflated 68%)
#   adding: KiwKiw/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: KiwKiw/.git/hooks/pre-push.sample (deflated 49%)
#   adding: KiwKiw/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: KiwKiw/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: KiwKiw/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: KiwKiw/.git/description (deflated 14%)
#   adding: KiwKiw/.git/index (deflated 58%)
#   adding: KiwKiw/.git/info/ (stored 0%)
#   adding: KiwKiw/.git/info/exclude (deflated 28%)
#   adding: KiwKiw/.git/branches/ (stored 0%)
#   adding: KiwKiw/.git/packed-refs (deflated 44%)
#   adding: KiwKiw/.git/refs/ (stored 0%)
#   adding: KiwKiw/.git/refs/remotes/ (stored 0%)
#   adding: KiwKiw/.git/refs/remotes/origin/ (stored 0%)
#   adding: KiwKiw/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: KiwKiw/.git/refs/tags/ (stored 0%)
#   adding: KiwKiw/.git/refs/heads/ (stored 0%)
#   adding: KiwKiw/.git/refs/heads/main (stored 0%)
#   adding: KiwKiw/go-web.bat (deflated 19%)
#   adding: KiwKiw/docs/ (stored 0%)
#   adding: KiwKiw/docs/jp/ (stored 0%)
#   adding: KiwKiw/docs/jp/faiss_tips_ja.md (deflated 55%)
#   adding: KiwKiw/docs/jp/Changelog_JA.md (deflated 60%)
#   adding: KiwKiw/docs/jp/faq_ja.md (deflated 63%)
#   adding: KiwKiw/docs/jp/README.ja.md (deflated 60%)
#   adding: KiwKiw/docs/jp/training_tips_ja.md (deflated 59%)
#   adding: KiwKiw/docs/en/ (stored 0%)
#   adding: KiwKiw/docs/en/README.en.md (deflated 60%)
#   adding: KiwKiw/docs/en/faq_en.md (deflated 57%)
#   adding: KiwKiw/docs/en/faiss_tips_en.md (deflated 57%)
#   adding: KiwKiw/docs/en/Changelog_EN.md (deflated 56%)
#   adding: KiwKiw/docs/en/training_tips_en.md (deflated 59%)
#   adding: KiwKiw/docs/fr/ (stored 0%)
#   adding: KiwKiw/docs/fr/training_tips_fr.md (deflated 61%)
#   adding: KiwKiw/docs/fr/faq_fr.md (deflated 64%)
#   adding: KiwKiw/docs/fr/README.fr.md (deflated 60%)
#   adding: KiwKiw/docs/fr/faiss_tips_fr.md (deflated 58%)
#   adding: KiwKiw/docs/fr/Changelog_FR.md (deflated 62%)
#   adding: KiwKiw/docs/cn/ (stored 0%)
#   adding: KiwKiw/docs/cn/Changelog_CN.md (deflated 46%)
#   adding: KiwKiw/docs/cn/faq.md (deflated 47%)
#   adding: KiwKiw/docs/小白简易教程.doc (deflated 4%)
#   adding: KiwKiw/docs/pt/ (stored 0%)
#   adding: KiwKiw/docs/pt/README.pt.md (deflated 59%)
#   adding: KiwKiw/docs/pt/Changelog_pt.md (deflated 60%)
#   adding: KiwKiw/docs/pt/faq_pt.md (deflated 60%)
#   adding: KiwKiw/docs/pt/faiss_tips_pt.md (deflated 57%)
#   adding: KiwKiw/docs/pt/training_tips_pt.md (deflated 59%)
#   adding: KiwKiw/docs/kr/ (stored 0%)
#   adding: KiwKiw/docs/kr/faiss_tips_ko.md (deflated 55%)
#   adding: KiwKiw/docs/kr/Changelog_KO.md (deflated 56%)
#   adding: KiwKiw/docs/kr/faq_ko.md (deflated 59%)
#   adding: KiwKiw/docs/kr/training_tips_ko.md (deflated 56%)
#   adding: KiwKiw/docs/kr/README.ko.md (deflated 57%)
#   adding: KiwKiw/docs/kr/README.ko.han.md (deflated 51%)
#   adding: KiwKiw/docs/tr/ (stored 0%)
#   adding: KiwKiw/docs/tr/README.tr.md (deflated 59%)
#   adding: KiwKiw/docs/tr/faiss_tips_tr.md (deflated 56%)
#   adding: KiwKiw/docs/tr/faq_tr.md (deflated 57%)
#   adding: KiwKiw/docs/tr/Changelog_TR.md (deflated 61%)
#   adding: KiwKiw/docs/tr/training_tips_tr.md (deflated 59%)
#   adding: KiwKiw/requirements-dml.txt (deflated 38%)
#   adding: KiwKiw/requirements.txt (deflated 39%)
#   adding: KiwKiw/LICENSE (deflated 41%)
#   adding: KiwKiw/requirements-win-for-realtime_vc_gui.txt (deflated 42%)
#   adding: KiwKiw/gui_v1.py (deflated 84%)
#   adding: KiwKiw/run.sh (deflated 57%)
#   adding: KiwKiw/.gitignore (deflated 30%)
#   adding: KiwKiw/.env (deflated 35%)
#   adding: KiwKiw/api_240604.py (deflated 78%)
#   adding: KiwKiw/CONTRIBUTING.md (deflated 24%)
#   adding: KiwKiw/pyproject.toml (deflated 50%)
#   adding: KiwKiw/poetry.lock (deflated 69%)
#   adding: KiwKiw/requirements-ipex.txt (deflated 40%)
#   adding: KiwKiw/MIT协议暨相关引用库协议 (deflated 44%)
#   adding: KiwKiw/Retrieval_based_Voice_Conversion_WebUI_v2.ipynb (deflated 84%)
#   adding: KiwKiw/tools/ (stored 0%)
#   adding: KiwKiw/tools/infer_cli.py (deflated 66%)
#   adding: KiwKiw/tools/infer/ (stored 0%)
#   adding: KiwKiw/tools/infer/infer-pm-index256.py (deflated 65%)
#   adding: KiwKiw/tools/infer/trans_weights.py (deflated 66%)
#   adding: KiwKiw/tools/infer/train-index.py (deflated 42%)
#   adding: KiwKiw/tools/infer/train-index-v2.py (deflated 50%)
#   adding: KiwKiw/tools/download_models.py (deflated 68%)
#   adding: KiwKiw/tools/onnx_inference_demo.py (deflated 36%)
#   adding: KiwKiw/tools/calc_rvc_model_similarity.py (deflated 62%)
#   adding: KiwKiw/tools/app.py (deflated 64%)
#   adding: KiwKiw/tools/dlmodels.sh (deflated 74%)
#   adding: KiwKiw/tools/export_onnx.py (deflated 51%)
#   adding: KiwKiw/tools/rvc_for_realtime.py (deflated 74%)
#   adding: KiwKiw/tools/dlmodels.bat (deflated 89%)
#   adding: KiwKiw/tools/torchgate/ (stored 0%)
#   adding: KiwKiw/tools/torchgate/torchgate.py (deflated 76%)
#   adding: KiwKiw/tools/torchgate/__init__.py (deflated 46%)
#   adding: KiwKiw/tools/torchgate/utils.py (deflated 63%)
#   adding: KiwKiw/tools/infer_batch_rvc.py (deflated 68%)
#   adding: KiwKiw/go-realtime-gui-dml.bat (deflated 20%)
